# %%
# !pip install pyflac
# Out:
# ...
#      ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.8 MB 660.6 kB/s eta 0:00:03
#       --------------------------------------- 0.0/1.8 MB 660.6 kB/s eta 0:00:03
#       --------------------------------------- 0.0/1.8 MB 660.6 kB/s eta 0:00:03
#       --------------------------------------- 0.0/1.8 MB 660.6 kB/s eta 0:00:03
#       --------------------------------------- 0.0/1.8 MB 140.9 kB/s eta 0:00:13
#       --------------------------------------- 0.0/1.8 MB 140.9 kB/s eta 0:00:13
#      - -------------------------------------- 0.1/1.8 MB 262.6 kB/s eta 0:00:07
#      - -------------------------------------- 0.1/1.8 MB 262.6 kB/s eta 0:00:07
#      -- ------------------------------------- 0.1/1.8 MB 252.2 kB/s eta 0:00:07
#      -- ------------------------------------- 0.1/1.8 MB 252.2 kB/s eta 0:00:07
#      -- ------------------------------------- 0.1/1.8 MB 252.2 kB/s eta 0:00:07
# ...

# %%
# !python3 -m recipes.cad2.task2.process_dataset.process_zenodo_download
# Out:
# Copying metadata directory.
# ...
# Extracting CadenzaWoodwind: 100%|██████████| 172/172 [00:51<00:00,  3.35it/s]
#
# ...
# Extracting EnsembleSet_Mix_1: 100%|██████████| 548/548 [00:28<00:00, 19.55it/s]
#
# ...
# Extracting metadata: 100%|██████████| 18/18 [00:00<00:00, 491.92it/s]
#
# ...
# Copying training audio: 100%|██████████| 104/104 [00:26<00:00,  3.91it/s]
#
# ...
# Creating validation audio: 100%|██████████| 261/261 [01:18<00:00,  3.34it/s]
